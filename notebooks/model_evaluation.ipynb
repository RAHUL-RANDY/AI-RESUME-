# %% [markdown]
# # Model Evaluation & SHAP Explainability Verification

# %%
import joblib
import json

with open('../models/model_metadata.json') as f:
    meta = json.load(f)

print('Model Metadata & Benchmark Metrics:\n', json.dumps(meta, indent=2))
